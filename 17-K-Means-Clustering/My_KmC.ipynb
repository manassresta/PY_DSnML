# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
#%matplotlib inline

# %%
from sklearn.datasets import make_blobs

# %%
data = make_blobs(n_samples=200,n_features=2,centers = 4,cluster_std=1.8,
                 random_state=101)

# %%
data[0].shape
# Out:
# (200, 2)

# %%
from sklearn.datasets import make_blobs

# %%
plt.scatter(data[0][:,0],data[0][:,1],c=data[1],cmap='rainbow')

# %%
data[1]
# Out:
# array([3, 2, 0, 2, 2, 1, 2, 0, 2, 0, 3, 0, 2, 2, 3, 0, 2, 0, 1, 3, 1, 0,
#        0, 1, 3, 1, 1, 0, 2, 2, 3, 1, 2, 0, 0, 3, 1, 1, 1, 2, 1, 3, 3, 3,
#        0, 3, 3, 0, 1, 2, 0, 3, 2, 0, 1, 3, 0, 0, 3, 2, 1, 2, 1, 3, 2, 0,
#        1, 2, 2, 1, 2, 0, 1, 3, 1, 2, 2, 0, 3, 0, 0, 1, 2, 1, 0, 0, 0, 3,
#        2, 1, 1, 1, 1, 3, 0, 1, 2, 3, 1, 2, 0, 1, 0, 0, 2, 0, 1, 2, 1, 1,
#        0, 3, 3, 2, 1, 2, 3, 3, 2, 3, 0, 3, 0, 3, 0, 2, 3, 0, 1, 3, 3, 3,
#        0, 1, 1, 3, 2, 3, 2, 0, 1, 2, 1, 3, 3, 2, 0, 1, 3, 3, 3, 3, 0, 2,
#        0, 3, 2, 2, 2, 0, 2, 0, 0, 3, 1, 3, 0, 2, 3, 0, 2, 0, 3, 3, 0, 3,
#        2, 2, 1, 2, 3, 1, 1, 3, 1, 1, 1, 1, 1, 0, 1, 2, 2, 3, 1, 0, 2, 2,
#        1, 0])

# %%
from sklearn.cluster import KMeans

# %%
kmeans = KMeans(n_clusters=8)

# %%
kmeans.fit(data[0])
# Out:
# KMeans()

# %%
kmeans.cluster_centers_
# Out:
# array([[ -4.67940744,   7.98950994],
#        [ -8.71581731,  -6.44215505],
#        [  4.92722854,   4.93970692],
#        [  0.33250207,   0.6136543 ],
#        [  4.39404498,   8.21793177],
#        [-11.40724965,  -6.8659422 ],
#        [ -0.49282081,   4.00711394],
#        [  0.56571169,   7.97605916]])

# %%
kmeans.labels_
# Out:
# array([0, 2, 6, 7, 4, 5, 7, 3, 7, 6, 0, 6, 4, 2, 0, 3, 2, 3, 1, 0, 5, 3,
#        6, 5, 0, 1, 1, 3, 4, 2, 0, 1, 2, 3, 6, 0, 5, 5, 5, 3, 1, 0, 7, 0,
#        6, 7, 0, 6, 5, 6, 3, 0, 2, 3, 1, 6, 6, 3, 0, 4, 1, 7, 1, 7, 4, 3,
#        5, 2, 4, 1, 7, 6, 1, 6, 1, 2, 4, 3, 0, 6, 6, 1, 4, 1, 3, 3, 3, 0,
#        6, 1, 1, 1, 1, 6, 6, 1, 4, 0, 1, 2, 6, 5, 6, 3, 7, 6, 1, 4, 1, 1,
#        2, 0, 0, 7, 1, 2, 0, 0, 7, 7, 6, 0, 3, 0, 3, 2, 0, 3, 1, 0, 0, 0,
#        3, 1, 5, 0, 2, 6, 4, 3, 5, 2, 1, 7, 7, 7, 6, 1, 0, 0, 0, 0, 3, 2,
#        3, 0, 6, 4, 4, 3, 4, 3, 6, 0, 5, 0, 6, 4, 0, 3, 4, 3, 0, 7, 6, 0,
#        4, 7, 1, 7, 0, 1, 1, 7, 1, 5, 1, 1, 5, 3, 1, 4, 4, 0, 1, 6, 4, 4,
#        1, 3], dtype=int32)

# %%
f, (ax1, ax2) = plt.subplots(1, 2, sharey=True,figsize=(10,6))
ax1.set_title('K Means')
ax1.scatter(data[0][:,0],data[0][:,1],c=kmeans.labels_,cmap='rainbow')
ax2.set_title("Original")
ax2.scatter(data[0][:,0],data[0][:,1],c=data[1],cmap='rainbow')
